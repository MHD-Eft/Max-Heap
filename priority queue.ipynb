# %% [markdown]
# # <font color=brown>DATA STRUCTURE</font>
# ---
# ## <font color=green>Implementation of Priority Queue by using Max Heap</font>
#
# >#### Professor : `Ehsan Khadangi`
# >#### Teacher Assistant: `Ali Shafiee`
# >##### Author: `Mahdieh Eftekharian`
# >##### Date: `Summer 1401`
# ---

# %% [markdown]
# ## <font color=purple>پياده سازي صف اولویت</font>
# ### صف اولویت را می توان با استفاده از یک آرایه،  لیست پیوندی، داده ساختار هيپ یا درخت جستجوی دودویی پیاده سازی کرد. در میان این داده ساختارها ، داده ساختار هيپ پياده سازي کارآمد صف های اولویت را فراهم می کند.از این رو، ما از داده ساختارهای هيپ بيشينه برای پیاده سازی صف اولویت در این کد استفاده خواهیم کرد
# ### هیپ بیشینه درخت دودویی کاملی است که مقدار هر گره بیشتر یا مساوی فرزندان خود است.
# ### بیشترین مقدار موجود در درخت در ریشه هیپ بیشینه قرار می گیرد
# #### A Max heap is typically represented as an array:
# #### Arr[0] Returns the root node.
# #### Arr[(i)//2] Returns the parent node.
# #### Arr[(2*i)+1] Returns the left child node.
# #### Arr[(2*i)+2] Returns the right child node.

# %% [markdown]
# # <font color=purple>class MaxHeap</font>:

# %%
class MaxHeap:
    def __init__(self):
        self.Heap = []
        self.size = 0

	# Function to return the position of parent for the node currently at index
    def parent(self, index):
        return index // 2

	# Function to return existance of the left child for the node currently
    def leftChild(self, index):
        if ((2 * index) + 1 < len(self.Heap)) :
            return True
        else:
            return False

	# Function to return existance of the right child for the node currently
    def RightChild(self, index):
        if ((2 * index) + 2 < len(self.Heap)) :
            return True
        else:
            return False
    #This function copy passed heap to object by value    
    def copy(self,maxHeap : 'MaxHeap'):
        self.Heap=maxHeap.Heap.copy()
        self.size=len(self.Heap)   

	# returns true if the node is a leaf node
    def isLeaf(self, index):
		
        if index >= (self.size//2) and index < len(self.Heap):
            return True
        return False

	# swap two nodes of the heap
    def swap(self, findex, sindex):
        self.Heap[findex], self.Heap[sindex] = (self.Heap[sindex],self.Heap[findex])

	# fix the heap feature of tree
    def maxHeapify(self, index):

		# If the node is a non-leaf node and smaller than any of its child
        if not self.isLeaf(index):
            if (self.RightChild(index) and self.leftChild(index)):
                if (self.Heap[index] < self.Heap[(2 * index) + 1] or
					self.Heap[index] < self.Heap[(2 * index) + 2]):

					# Swap with the left child and heapify the left child
                    if (self.Heap[(2 * index) + 1] >
						self.Heap[(2 * index) + 2]):
                        self.swap(index, (2 * index) + 1)
                        self.maxHeapify((2 * index) + 1)

					# Swap with the right child and heapify the right child
                    else:
                        self.swap(index, (2 * index) + 2)
                        self.maxHeapify((2 * index) + 2)

            elif (self.leftChild(index) and self.Heap[index] < self.Heap[(2 * index) + 1] ):
                self.swap(index, (2 * index) + 1)

	#Inserting a node into the heap
    def insert(self, element):
		
        if (self.size > len(self.Heap)):
            return
        self.Heap.append(element) 
        current = self.size
        self.size += 1
        while (self.Heap[current] > self.Heap[self.parent(current)]):
            self.swap(current, self.parent(current))
            current = self.parent(current)


       
	#Printing the elements of the heap
    def Print(self):
		
        for i in range(0, (self.size // 2)):
            print("PARENT : " + str(self.Heap[i]) , end=" ")
            if ((2 * i) + 1 < len(self.Heap)) :
                print("LEFT CHILD : " + str(self.Heap[2 * i +1]) , end=" ")
            if ((2 * i) + 2 < len(self.Heap)) :
                print(	"RIGHT CHILD : " + str(self.Heap[2 * i + 2]))
        if (self.size ==1):
            print("PARENT : " + str(self.Heap[0]))
        print()
			

    
    
	# return and remove the maximum element from the heap
    def extract_max(self):
        if 1<len(self.Heap):
            max = self.Heap[0]
            self.size -= 1
            self.Heap[0] = self.Heap.pop()
            self.maxHeapify(0)
            return max
        elif 1==len(self.Heap):
            self.size -= 1
            return self.Heap.pop()
        return None
    
    #returns the maximum value of heap
    def find_max(self):
        if len(self.Heap):
            return self.Heap[0]

	#get two max heap and merge them into third max heap and return the third max heap
    #priority = 0 : normal merge with no priority
    #priority = 1 : gives the elements of first heap higher priority than second heap for merging into third heap
    #priority = 2 : gives the elements of second heap higher priority than first heap for merging into third heap

    def merge( self,maxHeap1 : 'MaxHeap' ,maxHeap2 : 'MaxHeap',priority = 0):
        len1=maxHeap1.size
        len2=maxHeap2.size
        mergedMaxHeap = MaxHeap()
        if priority == 0: 
            if len1 < len2:
                for i in range(len1):
                    mergedMaxHeap.insert(maxHeap1.extract_max())
                    mergedMaxHeap.insert(maxHeap2.extract_max())
                len2=maxHeap2.size
                for i in range(len2):
                    mergedMaxHeap.insert(maxHeap2.extract_max())
            elif len2 < len1:
                for i in range(len2):
                    mergedMaxHeap.insert(maxHeap1.extract_max())
                    mergedMaxHeap.insert(maxHeap2.extract_max())
                len1=maxHeap1.size
                for i in range(len1):
                    mergedMaxHeap.insert(maxHeap1.extract_max())
            else:
                for i in range(len2):
                    mergedMaxHeap.insert(maxHeap1.extract_max())
                    mergedMaxHeap.insert(maxHeap2.extract_max())

        elif priority == 1:
            if type(maxHeap2.find_max())==str :
                maxHeap1.add_to_all( 2*ord(maxHeap2.find_max()))
            else:
                maxHeap1.add_to_all( 2*maxHeap2.find_max())
            mergedMaxHeap = maxHeap1
            for i in range(len2):
                mergedMaxHeap.insert(maxHeap2.extract_max())

        elif priority == 2:
            if type(maxHeap1.find_max())==str :
                maxHeap2.add_to_all(2*ord(maxHeap1.find_max()))
            else:
                maxHeap2.add_to_all( 2*maxHeap1.find_max())
            mergedMaxHeap = maxHeap2
            for i in range(len1):
                mergedMaxHeap.insert(maxHeap1.extract_max())
		
        return mergedMaxHeap
    
    #Increases the priority of all elements of passed heap by adding k to elements
    def add_to_all(self , k):
        if self.size > 0 :
            if type(k)==str and type(self.Heap[0])==str:
                for i in range(self.size):
                    self.Heap[i]=chr(ord(self.Heap[i])+ord(k))

            elif type(k)==int and type(self.Heap[0])==str:
                for i in range(self.size):
                    self.Heap[i]=chr(ord(self.Heap[i])+k)
            elif type(k)==str:
                for i in range(self.size):
                    self.Heap[i]=self.Heap[i]+ord(k)
            else:
                for i in range(self.size):
                    self.Heap[i]=self.Heap[i]+k
        return

# %% [markdown]
# # <font color=purple>توضیحات</font>

# %% [markdown]
# ---
# ## <font color=purple>maxHeapify</font>

# %%
def maxHeapify(self, index):

    # If the node is a non-leaf node and smaller than any of its child
    if not self.isLeaf(index):
        if (self.RightChild(index) and self.leftChild(index)):
            if (self.Heap[index] < self.Heap[(2 * index) + 1] or
                self.Heap[index] < self.Heap[(2 * index) + 2]):

                # Swap with the left child and heapify the left child
                if (self.Heap[(2 * index) + 1] >
                    self.Heap[(2 * index) + 2]):
                    self.swap(index, (2 * index) + 1)
                    self.maxHeapify((2 * index) + 1)

                # Swap with the right child and heapify the right child
                else:
                    self.swap(index, (2 * index) + 2)
                    self.maxHeapify((2 * index) + 2)

        elif (self.leftChild(index) and self.Heap[index] < self.Heap[(2 * index) + 1] ):
            self.swap(index, (2 * index) + 1)

# %% [markdown]
# ### این تابع قرار است ویژگی درخت هیپ یعنی بزرگتر مساوی بودن هر گره از فرزندان خود را تامین کند
# ### به این تابع ایندکس عنصری که ویژگی درخت هیپ را نقض می کند پاس داده می شود
# ### سپس بررسی می شود عنصر برگ نباشد چراکه برگ فرزندی ندارد و ویژگی درخت را نقض نمی کند.
# ### اگر عنصر دارای دو فرزند بود فرزند با فرزند بزرگتر خودش جا به جا می شود
# ### حال دوباره تابع به صورت بازگشتی روی ایندکس جدید عنصر متناقض ویژگی درخت هیپ فراخوانی می شود
# ### تا اگر از فرزندادن جدید خود کوچک تر بود با جا به جایی اصلاح شود
# ### این روال ادامه می یابد تا زمانی که عنصر از فرزندان خود کوچکتر نباشد یا عنصر تبدیل به برگ درخت شده باشد
# ### اگر عنصر تنها یک فرزند داشته باشد قطعا فرزند چپ آن است چراکه درخت هیپ درخت دودویی کامل است پس فقط بزرگتر بودن فرزند چپ را بررسی می کنیم.
# ### : پیچیدگی زمانی تابع
# ### Worst Case: O(logn)
# ### n: number of elements of heap

# %% [markdown]
# ---
# ## <font color=purple>insert</font>

# %%
def insert(self, element):

    if (self.size > len(self.Heap)):
        return
    self.Heap.append(element) 
    current = self.size
    self.size += 1
    while (self.Heap[current] > self.Heap[self.parent(current)]):
        self.swap(current, self.parent(current))
        current = self.parent(current)

# %% [markdown]
# ### این تابع یک مقدار از ورودی دریافت می کند و در انتهای درخت هیپ درج می کند اگرعنصر از والد خود بزرگتر باشد ویژگی درخت هیپ را نقض کرده است
# ### برای اصلاح درخت عنصر را با والدش جا به جا می کنیم تا جایی که دیگر والدش کوچکتر از آن عنصر نباشد
# ### یا عنصر تبدیل به ریشه درخت شده باشد
# ### : پیچیدگی زمانی تابع
# ### Worst Case: O(logn)
# ### n: number of elements of heap
# ---

# %% [markdown]
# ---
# ## <font color=purple>extract_max</font>

# %%
def extract_max(self):
    if 1<len(self.Heap):
        max = self.Heap[0]
        self.size -= 1
        self.Heap[0] = self.Heap.pop()
        self.maxHeapify(0)
        return max
    elif 1==len(self.Heap):
        self.size -= 1
        return self.Heap.pop()
    return None

# %% [markdown]
# ### این تابع ریشه درخت هیپ را که ماکسیمم مقدار را داراست خروجی می دهد و آخرین عنصر هیپ را در ریشه جایگزین می کند تا ویژگی کامل بودن درخت حفظ شود  و از اندازه آرایه یک عدد کم می کند با این کار در اکثر مواقع ویژگی بزرگتر مساوی بودن هر گره از فرزندان خود درخت هیپ نقض می شود پس برای اصلاح درخت تابع
# #### `self.maxHeapify(0)`
# ### فراخوانی می شود
# ### اگر هیپ دارای یک عنصر باشد فراخوانی این تابع نیاز نیست
# ### : پیچیدگی زمانی تابع
# ### Worst Case: O(logn)
# ### n: number of elements of heap
# ---

# %% [markdown]
# ---
# ## <font color=purple>find_max</font>

# %%
def find_max(self):
    if len(self.Heap):
        return self.Heap[0]

# %% [markdown]
# ### این تابع ماکسیمم مقدار هیپ که واقع در ریشه آن است خروجی می دهد
# ### : پیچیدگی زمانی تابع
# ### Worst Case: O(1)
# ---

# %% [markdown]
# ---
# ## <font color=purple>merge</font>

# %%
def merge( self,maxHeap1 : 'MaxHeap' ,maxHeap2 : 'MaxHeap',priority = 0):
    len1=maxHeap1.size
    len2=maxHeap2.size
    mergedMaxHeap = MaxHeap()
    if priority == 0: 
        if len1 < len2:
            for i in range(len1):
                mergedMaxHeap.insert(maxHeap1.extract_max())
                mergedMaxHeap.insert(maxHeap2.extract_max())
            len2=maxHeap2.size
            for i in range(len2):
                mergedMaxHeap.insert(maxHeap2.extract_max())
        elif len2 < len1:
            for i in range(len2):
                mergedMaxHeap.insert(maxHeap1.extract_max())
                mergedMaxHeap.insert(maxHeap2.extract_max())
            len1=maxHeap1.size
            for i in range(len1):
                mergedMaxHeap.insert(maxHeap1.extract_max())
        else:
            for i in range(len2):
                mergedMaxHeap.insert(maxHeap1.extract_max())
                mergedMaxHeap.insert(maxHeap2.extract_max())

    elif priority == 1:
        if type(maxHeap2.find_max())==str :
            maxHeap1.add_to_all( 2*ord(maxHeap2.find_max()))
        else:
            maxHeap1.add_to_all( 2*maxHeap2.find_max())
        mergedMaxHeap = maxHeap1
        for i in range(len2):
            mergedMaxHeap.insert(maxHeap2.extract_max())

    elif priority == 2:
        if type(maxHeap1.find_max())==str :
            maxHeap2.add_to_all(2*ord(maxHeap1.find_max()))
        else:
            maxHeap2.add_to_all( 2*maxHeap1.find_max())
        mergedMaxHeap = maxHeap2
        for i in range(len1):
            mergedMaxHeap.insert(maxHeap1.extract_max())

    return mergedMaxHeap

# %% [markdown]
# ### این تابع دو داده ساختار هیپ را از ورودی دریافت می کند و تمام عناصر این دو هیپ را در هیپ سوم ذخیره می کند و هیپ جدید را خروجی می دهد
# ### `وارد کردن اولویت در تابع اختیاری است`
# >### priority = 0 :
# >### در زمانی که اولویتی بندی در دو هیپ داده شده به تابع وجود نداشته باشد عناصر هیپ به صورت نوبتی یکی از هیپ اول و دیگری از هیپ دوم خارج شده و در هیپ جدید درج می شوند. اولویت تابع به صورت پیش فرض 0 است
# ---
# >### priority = 1 :
# >### در این حالت اولویت با عناصر هیپ اول است .
# >### برای اینکه این اولویت را روی عناصر هیپ اول اعمال کنیم با تابع
# >#### `add_to_all`
# >### دو برابر ماکسیمم هیپ دوم را به عناصر هیپ اول اضافه می کینم چراکه اگر دقیقا مقدار ماکس را اضافه کنیم ممکن است عناصر مینیمم هیپ اول صفر باشند و با ماکس هیپ دوم برابر شوند ، برای اینکه تضمین کنیم اولویت با عناصر هیپ اول است دو برابر ماکس هیپ دوم را به عناصر آن اضافه می کنیم.
# ---
# >### priority = 2 :
# >### در این حالت اولویت با عناصر هیپ دوم است .
# >### برای اعمال اولویت روی عناصر هیپ دوم دقیقا عملیات ذکر شده قسمت قبل را برای هیپ دوم تکرار می کنیم
# >### به تمام عناصر هیپ دوم به اندازه دو برابر ماکس هیپ اول اضافه می شود
# ---
# >#### `برای اینکه اولویت دهی به هیپ ها به درستی انجام شود باید مقدار درج شده در آنها هم علامت باشند `
#
# ### : پیچیدگی زمانی تابع اگر تعداد عناصر دو هیپ برابر باشند
# ### Worst Case: O(nlogn)
# ### n: number of elements of heap
# ---

# %% [markdown]
# ---
# ## <font color=purple>add_to_all</font>

# %%
def add_to_all(self , k):
    if self.size > 0 :
        if type(k)==str and type(self.Heap[0])==str:
            for i in range(self.size):
                self.Heap[i]=chr(ord(self.Heap[i])+ord(k))

        elif type(k)==int and type(self.Heap[0])==str:
            for i in range(self.size):
                self.Heap[i]=chr(ord(self.Heap[i])+k)
        elif type(k)==str:
            for i in range(self.size):
                self.Heap[i]=self.Heap[i]+ord(k)
        else:
            for i in range(self.size):
                self.Heap[i]=self.Heap[i]+k
    return

# %% [markdown]
# ### در اين تابع يك مقدار به اسم كا به عنوان ورودي دريافت مي شود كه قرار است اين مقدار به تمام عناصر شيء هيپ اضافه شود .
# ### : در بدنه تابع بررسي مي شود
#
# ### اگر عناصر هيپ به صورت كاراكتر بودند ، مقدار كا يا عدد اسكي كا در صورتيكه خود كا كاراكتر باشد به تك تك عدد اسكي كاراكتر هاي درون عناصر هيپ اضافه مي شود و كاراكتر جديد توليد مي شود و در هيپ جايگزين مي شود.
#
# ###  اگر عناصر هيپ عدد باشند مقدار كا یک کاراکتر باشد عدد اسکی کاراکتر کا به عدد عناصر هیپ اضافه می شود
# ###  و اگر کا عدد باشد به سادگي به عدد عناصر هيپ اضافه مي شود
# ### :پيچيدگي زماني اين تابع به تعداد عناصر هيپ بستگي دارد
# ### Worst Case: O(n)
# ### n: number of elements of heap
# ---
